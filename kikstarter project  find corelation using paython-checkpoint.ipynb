# %%
#Load the Librarys
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
#loading the data 
df = pd.read_csv(r'C:\Users\salah\Downloads\ks-projects-201801.csv')

# %%
#Looking the data
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# 0                Poetry    Publishing      GBP  2015-10-09   1000.0
# 1        Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2        Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3                 Music         Music      USD  2012-04-16   5000.0
# 4          Film & Video  Film & Video      USD  2015-08-29  19500.0
# ...                 ...           ...      ...         ...      ...
# 378656      Documentary  Film & Video      USD  2014-10-17  50000.0
# 378657   Narrative Film  Film & Video      USD  2011-07-19   1500.0
# 378658   Narrative Film  Film & Video      USD  2010-08-16  15000.0
# 378659       Technology    Technology      USD  2016-02-13  15000.0
# 378660  Performance Art           Art      USD  2011-08-16   2000.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# 0       2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1       2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2       2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3       2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4       2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
# ...                     ...      ...       ...      ...     ...          ...
# 378656  2014-09-17 02:35:30     25.0  canceled        1      US         25.0
# 378657  2011-06-22 03:35:14    155.0    failed        5      US        155.0
# 378658  2010-07-01 19:40:30     20.0    failed        1      US         20.0
# 378659  2016-01-13 18:13:53    200.0    failed        6      US        200.0
# 378660  2011-07-19 09:07:47    524.0    failed       17      US        524.0
#
#         usd_pledged_real  usd_goal_real
# 0                    0.0        1533.95
# 1                 2421.0       30000.00
# 2                  220.0       45000.00
# 3                    1.0        5000.00
# 4                 1283.0       19500.00
# ...                  ...            ...
# 378656              25.0       50000.00
# 378657             155.0        1500.00
# 378658              20.0       15000.00
# 378659             200.0       15000.00
# 378660             524.0        2000.00
#
# [378661 rows x 15 columns]

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# ID - 0%
# name - 0%
# category - 0%
# main_category - 0%
# currency - 0%
# deadline - 0%
# goal - 0%
# launched - 0%
# pledged - 0%
# state - 0%
# backers - 0%
# country - 0%
# usd pledged - 1%
# usd_pledged_real - 0%
# usd_goal_real - 0%

# %%
# remove non value to zeos
df['usd pledged'] = df['usd pledged'].fillna(0)

# %% [markdown]
# # Knowing our data

# %%
# see if we have any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# ID - 0%
# name - 0%
# category - 0%
# main_category - 0%
# currency - 0%
# deadline - 0%
# goal - 0%
# launched - 0%
# pledged - 0%
# state - 0%
# backers - 0%
# country - 0%
# usd pledged - 0%
# usd_pledged_real - 0%
# usd_goal_real - 0%

# %%
# quick summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378661 entries, 0 to 378660
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                378661 non-null  int64
#  1   name              378657 non-null  object
#  2   category          378661 non-null  object
#  3   main_category     378661 non-null  object
#  4   currency          378661 non-null  object
#  5   deadline          378661 non-null  object
#  6   goal              378661 non-null  float64
#  7   launched          378661 non-null  object
#  8   pledged           378661 non-null  float64
#  9   state             378661 non-null  object
#  10  backers           378661 non-null  int64
#  11  country           378661 non-null  object
#  12  usd pledged       378661 non-null  float64
#  13  usd_pledged_real  378661 non-null  float64
#  14  usd_goal_real     378661 non-null  float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 43.3+ MB

# %%
# change the type of id column
df['ID'] = df['ID'].astype('object')

# %%
# Drop any duplicates
df.drop_duplicates()
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# 0                Poetry    Publishing      GBP  2015-10-09   1000.0
# 1        Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2        Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3                 Music         Music      USD  2012-04-16   5000.0
# 4          Film & Video  Film & Video      USD  2015-08-29  19500.0
# ...                 ...           ...      ...         ...      ...
# 378656      Documentary  Film & Video      USD  2014-10-17  50000.0
# 378657   Narrative Film  Film & Video      USD  2011-07-19   1500.0
# 378658   Narrative Film  Film & Video      USD  2010-08-16  15000.0
# 378659       Technology    Technology      USD  2016-02-13  15000.0
# 378660  Performance Art           Art      USD  2011-08-16   2000.0
#
#                    launched  pledged     state  backers country  usd pledged  \
# 0       2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1       2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2       2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3       2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4       2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
# ...                     ...      ...       ...      ...     ...          ...
# 378656  2014-09-17 02:35:30     25.0  canceled        1      US         25.0
# 378657  2011-06-22 03:35:14    155.0    failed        5      US        155.0
# 378658  2010-07-01 19:40:30     20.0    failed        1      US         20.0
# 378659  2016-01-13 18:13:53    200.0    failed        6      US        200.0
# 378660  2011-07-19 09:07:47    524.0    failed       17      US        524.0
#
#         usd_pledged_real  usd_goal_real
# 0                    0.0        1533.95
# 1                 2421.0       30000.00
# 2                  220.0       45000.00
# 3                    1.0        5000.00
# 4                 1283.0       19500.00
# ...                  ...            ...
# 378656              25.0       50000.00
# 378657             155.0        1500.00
# 378658              20.0       15000.00
# 378659             200.0       15000.00
# 378660             524.0        2000.00
#
# [378661 rows x 15 columns]

# %% [markdown]
# # look for the correlation among the columns.

# %%
# Correlation Matrix between all numeric columns
df.corr()
# Out:
#                       goal   pledged   backers  usd pledged  usd_pledged_real  \
# goal              1.000000  0.007358  0.004012     0.005567          0.005104
# pledged           0.007358  1.000000  0.717079     0.856429          0.952843
# backers           0.004012  0.717079  1.000000     0.697455          0.752539
# usd pledged       0.005567  0.856429  0.697455     1.000000          0.906639
# usd_pledged_real  0.005104  0.952843  0.752539     0.906639          1.000000
# usd_goal_real     0.942692  0.005024  0.004517     0.006204          0.005596
#
#                   usd_goal_real
# goal                   0.942692
# pledged                0.005024
# backers                0.004517
# usd pledged            0.006204
# usd_pledged_real       0.005596
# usd_goal_real          1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("projects features")

plt.ylabel("projects features")

plt.show()

# %%
# Correlation Matrix between all columns
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                         ID      name  category  main_category  currency  \
# ID                1.000000  0.991394 -0.001264       0.003078 -0.000149
# name              0.991394  1.000000 -0.001529       0.004795  0.000252
# category         -0.001264 -0.001529  1.000000       0.246779  0.038087
# main_category     0.003078  0.004795  0.246779       1.000000  0.074473
# currency         -0.000149  0.000252  0.038087       0.074473  1.000000
# deadline          0.010307  0.010433 -0.053645      -0.037477 -0.018414
# goal              0.055150  0.055353  0.005907      -0.003529  0.013740
# launched          0.998437  0.989837 -0.001358       0.002890 -0.000278
# pledged           0.180892  0.181396 -0.068624      -0.001534  0.017067
# state            -0.002266 -0.002420 -0.042988      -0.043846 -0.029636
# backers           0.025451  0.026620 -0.053541       0.030115 -0.011393
# country          -0.000330 -0.000486  0.009626       0.047873  0.892102
# usd pledged       0.254896  0.254251 -0.032005       0.033548  0.129888
# usd_pledged_real  0.274868  0.273572 -0.028876       0.035757  0.163173
# usd_goal_real     0.166045  0.164260  0.045010       0.067180  0.388977
#
#                   deadline      goal  launched   pledged     state   backers  \
# ID                0.010307  0.055150  0.998437  0.180892 -0.002266  0.025451
# name              0.010433  0.055353  0.989837  0.181396 -0.002420  0.026620
# category         -0.053645  0.005907 -0.001358 -0.068624 -0.042988 -0.053541
# main_category    -0.037477 -0.003529  0.002890 -0.001534 -0.043846  0.030115
# currency         -0.018414  0.013740 -0.000278  0.017067 -0.029636 -0.011393
# deadline          1.000000  0.003409  0.010667  0.016304  0.036652 -0.004575
# goal              0.003409  1.000000  0.055137  0.027117 -0.017025 -0.001592
# launched          0.010667  0.055137  1.000000  0.180738 -0.002165  0.025391
# pledged           0.016304  0.027117  0.180738  1.000000  0.375360  0.493175
# state             0.036652 -0.017025 -0.002165  0.375360  1.000000  0.285523
# backers          -0.004575 -0.001592  0.025391  0.493175  0.285523  1.000000
# country          -0.026194  0.010006 -0.000451  0.007171  0.059652 -0.020890
# usd pledged      -0.009516  0.025046  0.254735  0.674886  0.265521  0.347759
# usd_pledged_real -0.007106  0.026278  0.274592  0.731574  0.292641  0.358264
# usd_goal_real    -0.034360  0.400697  0.165825  0.023152 -0.030251 -0.012974
#
#                    country  usd pledged  usd_pledged_real  usd_goal_real
# ID               -0.000330     0.254896          0.274868       0.166045
# name             -0.000486     0.254251          0.273572       0.164260
# category          0.009626    -0.032005         -0.028876       0.045010
# main_category     0.047873     0.033548          0.035757       0.067180
# currency          0.892102     0.129888          0.163173       0.388977
# deadline         -0.026194    -0.009516         -0.007106      -0.034360
# goal              0.010006     0.025046          0.026278       0.400697
# launched         -0.000451     0.254735          0.274592       0.165825
# pledged           0.007171     0.674886          0.731574       0.023152
# state             0.059652     0.265521          0.292641      -0.030251
# backers          -0.020890     0.347759          0.358264      -0.012974
# country           1.000000     0.114916          0.158648       0.361584
# usd pledged       0.114916     1.000000          0.873761       0.354114
# usd_pledged_real  0.158648     0.873761          1.000000       0.383492
# usd_goal_real     0.361584     0.354114          0.383492       1.000000

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# sort Correlation Matrix

correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()


sorted_pairs = corr_pairs.sort_values(kind="quicksort")

# %%
# take a look for the strong Correlation pairs

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.45]

print(strong_pairs)
# Out:
# pledged           backers             0.493175
# backers           pledged             0.493175
# usd pledged       pledged             0.674886
# pledged           usd pledged         0.674886
#                   usd_pledged_real    0.731574
# usd_pledged_real  pledged             0.731574
#                   usd pledged         0.873761
# usd pledged       usd_pledged_real    0.873761
# country           currency            0.892102
# currency          country             0.892102
# launched          name                0.989837
# name              launched            0.989837
# ID                name                0.991394
# name              ID                  0.991394
# launched          ID                  0.998437
# ID                launched            0.998437
#                   ID                  1.000000
# launched          launched            1.000000
# usd pledged       usd pledged         1.000000
# country           country             1.000000
# backers           backers             1.000000
# state             state               1.000000
# pledged           pledged             1.000000
# goal              goal                1.000000
# deadline          deadline            1.000000
# currency          currency            1.000000
# main_category     main_category       1.000000
# category          category            1.000000
# name              name                1.000000
# usd_pledged_real  usd_pledged_real    1.000000
# usd_goal_real     usd_goal_real       1.000000
# dtype: float64

# %% [raw]
# we didn't find any significant correlation between states of the projects and any other column  such as  country or currency or category or main category columns such what we expected,  and there is a smallest correlation between numbers of backers and the some of money plagued and the state of the project and that probably means that the project who get more number of  interests from backers probably had more chance to get more money and achieve their objectives.
